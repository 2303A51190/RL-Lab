# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51190/RL-Lab/blob/main/RL_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# RANDOM AGENT FOR CLIFFWALKING AND TAXI
# ============================================================

# !pip install -q -U gymnasium

import gymnasium as gym


def random_agent(environment_name, number_of_episodes=5):

    env = gym.make(environment_name)

    print("\n" + "=" * 60)
    print("Environment:", environment_name)
    print("=" * 60)

    for episode in range(1, number_of_episodes + 1):

        # Reset environment
        state, info = env.reset()

        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        # State -> Action -> Reward -> Next State
        while not (terminated or truncated):

            # Select random action
            action = env.action_space.sample()

            # Execute action
            next_state, reward, terminated, truncated, info = env.step(action)

            # Update total reward
            total_reward += reward
            steps += 1

            # Move to next state
            state = next_state

        # Calculate average reward
        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Number of Steps:", steps)
        print("Average Reward:", round(average_reward, 2))
        print("-" * 60)

    env.close()


# ============================================================
# CLIFFWALKING
# ============================================================

random_agent("CliffWalking-v1", 5)


# ============================================================
# TAXI
# ============================================================

random_agent("Taxi-v4", 5)
# Out:
# ============================================================
# Environment: CliffWalking-v1
# ============================================================
# Episode: 1
# Total Reward: -12759
# Number of Steps: 1077
# Average Reward: -11.85
# ------------------------------------------------------------
# Episode: 2
# Total Reward: -101800
# Number of Steps: 10324
# Average Reward: -9.86
# ------------------------------------------------------------
# Episode: 3
# Total Reward: -112195
# Number of Steps: 10621
# Average Reward: -10.56
# ------------------------------------------------------------
# Episode: 4
# Total Reward: -37302
# Number of Steps: 3840
# Average Reward: -9.71
# ------------------------------------------------------------
# Episode: 5
# Total Reward: -1326
# Number of Steps: 237
# Average Reward: -5.59
# ------------------------------------------------------------
#
# ============================================================
# Environment: Taxi-v4
# ============================================================
# Episode: 1
# Total Reward: -749
# Number of Steps: 200
# Average Reward: -3.75
# ------------------------------------------------------------
# Episode: 2
# Total Reward: -857
# Number of Steps: 200
# Average Reward: -4.29
# ------------------------------------------------------------
# Episode: 3
# Total Reward: -848
# Number of Steps: 200
# Average Reward: -4.24
# ------------------------------------------------------------
# Episode: 4
# Total Reward: -704
# Number of Steps: 200
# Average Reward: -3.52
# ------------------------------------------------------------
# Episode: 5
# Total Reward: -659
# Number of Steps: 200
# Average Reward: -3.29
# ------------------------------------------------------------
