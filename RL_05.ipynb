# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51190/RL-Lab/blob/main/RL_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "gymnasium[classic-control]"

import gymnasium as gym

def random_agent(environment_name):


    env = gym.make(environment_name)


    state, info = env.reset()

    total_reward = 0
    step_count = 0

    print("\n" + "=" * 50)
    print("Selected Environment:", environment_name)
    print("=" * 50)


    print("Initial State:", state)


    print("Available Actions:", env.action_space)


    while True:


        action = env.action_space.sample()


        print("Step:", step_count + 1, "| Action:", action)


        next_state, reward, terminated, truncated, info = env.step(action)


        print("Reward:", reward)


        total_reward += reward


        step_count += 1


        state = next_state


        if terminated or truncated:
            break


    average_reward = total_reward / step_count

    print("\nEpisode Finished")
    print("Total Steps:", step_count)
    print("Total Reward:", total_reward)
    print("Average Reward:", average_reward)


    env.close()

    return total_reward, average_reward



print("==========================================")
print("     RANDOM AGENT - REINFORCEMENT LEARNING")
print("==========================================")

print("\nAvailable Environments:")
print("1. CartPole")
print("2. MountainCar")
print("3. FrozenLake")

choice = input("\nEnter your choice (1/2/3): ")


if choice == "1":
    environment = "CartPole-v1"

elif choice == "2":
    environment = "MountainCar-v0"

elif choice == "3":
    environment = "FrozenLake-v1"

else:
    print("Invalid choice! Please enter 1, 2, or 3.")
    environment = None




if environment is not None:

    total_reward, average_reward = random_agent(environment)

    # Final result
    print("\n" + "=" * 50)
    print("FINAL RESULT")
    print("=" * 50)
    print("Environment:", environment)
    print("Total Reward:", total_reward)
    print("Average Reward:", average_reward)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 49.0 MB/s eta 0:00:00
# ==========================================
#      RANDOM AGENT - REINFORCEMENT LEARNING
# ==========================================
#
# Available Environments:
# 1. CartPole
# 2. MountainCar
# 3. FrozenLake
